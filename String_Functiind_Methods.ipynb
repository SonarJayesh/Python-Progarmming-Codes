# %%
"""
String Functions/Methods
    • all string functions return new values because strings are immutable
"""

# %%
"""
1. capitalize()
    • capitalizes(convert lower case to upper case) the first character of the string
"""
s1 = 'hello Python'
s1.capitalize()
# Out:
# 'Hello python'

# %%
s1 = s1.capitalize()

# %%
s1
# Out:
# 'Hello python'

# %%
"""
2. Upper case
    convert string from lower case to upper case
    e.g string.upper()
"""

s1.upper()
# Out:
# 'HELLO PYTHON'

# %%
s1
# Out:
# 'Hello python'

# %%
s1 = s1.upper()

# %%
s1
# Out:
# 'HELLO PYTHON'

# %%
pan = 'abcd7657z'
pan.upper()
# Out:
# 'ABCD7657Z'

# %%
"""
3. Lower case
    converts upper to lower case
    e.g string.lower()
"""
s1
# Out:
# 'HELLO PYTHON'

# %%
s1.lower()
# Out:
# 'hello python'

# %%
"""
4. Title case
    capitalizes first letter of each word in the string
    e.g string.title()
"""
s2 = "united stated of america"
s2.title()
# Out:
# 'United Stated Of America'

# %%
s1.title()
# Out:
# 'Hello Python'

# %%
"""
5. Casefold
    stronger version of lower() function
    converts some special symbols to lower
    e.g string.casefold()
"""

word = 'Scheiße'
word.lower()
# Out:
# 'scheiße'

# %%
word.casefold()
# Out:
# 'scheisse'

# %%
"""
6. lstrip()
    removes the leading(on left side) white spaces from the string
    e.g string.lstrip()
"""
string = '        python'
string
# Out:
# '        python'

# %%
string.lstrip()
# Out:
# 'python'

# %%
"""
7. rstrip()
    removes the trailing(on right side) white spaces
    e.g string.rstrip()
"""
string = 'python     '
string
# Out:
# 'python     '

# %%
string.rstrip()
# Out:
# 'python'

# %%
"""
8. strip()
    removes the leading as well as trailing white spaces
    e.g string.strip()
"""
string = '      Data Science     '
string
# Out:
# '      Data Science     '

# %%
string.strip()
# Out:
# 'Data Science'

# %%
'''
9. swapcase()
    inverts the case of all char in the string(upper <--> lower)
    e.g string.swapcase()
'''

string = 'DatA sCiENce AnD mAChINe learNING'
string
# Out:
# 'DatA sCiENce AnD mAChINe learNING'

# %%
string.swapcase()
# Out:
# 'dATa ScIenCE aNd MacHinE LEARning'

# %%
'''
10. replace()
    used for replacing a part of string(char or word) by another char or word
    syntax: string.replace('old_str', 'new_str', count=-1)
'''
s1 = 'Data %^& Science'
s1.replace('%^&', '')
# Out:
# 'Data  Science'

# %%
string
# Out:
# 'DatA sCiENce AnD mAChINe learNING'

# %%
string.replace('e','-')
# Out:
# 'DatA sCiENc- AnD mAChIN- l-arNING'

# %%
string.replace('e','-',1)
# Out:
# 'DatA sCiENc- AnD mAChINe learNING'

# %%
string.replace('e','-',2)
# Out:
# 'DatA sCiENc- AnD mAChIN- learNING'

# %%
# remove all vowels from the string
s1 = "London bridge is falling down"
s1.replace('a','')
# Out:
# 'London bridge is flling down'

# %%
s1
# Out:
# 'London bridge is falling down'

# %%
s1 = s1.replace('a','')
print(s1)
s1 = s1.replace('e','')
print(s1)
s1 = s1.replace('i','')
print(s1)
s1 = s1.replace('o','')
print(s1)
s1 = s1.replace('u','')
print(s1)
# Out:
# London bridge is flling down
# London bridg is flling down
# London brdg s fllng down
# Lndn brdg s fllng dwn
# Lndn brdg s fllng dwn

# %%
s1 = 'London bridge is falling down'
s1
# Out:
# 'London bridge is falling down'

# %%
# method2
s1 = s1.replace('a','').replace('e','').replace('i','').replace('o','').replace('u','')
s1
# Out:
# 'Lndn brdg s fllng dwn'

# %%
'''
11. split()
    converts a string to list
    we can split the string by a particular char
    syntax: string.split(sep=None, maxsplit=-1)
        default separator is space
'''

s1 = 'London bridge is falling down'
s1
# Out:
# 'London bridge is falling down'

# %%
s1.split()
# Out:
# ['London', 'bridge', 'is', 'falling', 'down']

# %%
s1.split('i')
# Out:
# ['London br', 'dge ', 's fall', 'ng down']

# %%
list1 = s1.split('i') 
list1
# Out:
# ['London br', 'dge ', 's fall', 'ng down']

# %%
type(list1)
# Out:
# list

# %%
'''
12. count()
    return the number of non-overlapping occurences of a sub string
    syntax: string.count('sub_str', start_index, end_index)
'''
s1
# Out:
# 'London bridge is falling down'

# %%
s1.count('i')
# Out:
# 3

# %%
s1.count('i',7,16)
# Out:
# 2

# %%
'''
13. len()
    returns the length of string
    syntax: len(string)
'''

string
# Out:
# 'DatA sCiENce AnD mAChINe learNING'

# %%
len(string)
# Out:
# 33

# %%
s1
# Out:
# 'London bridge is falling down'

# %%
len(s1)
# Out:
# 29

# %%
'''
14. index()
    returns the index of a particular char
    in case of multiple occurences, returns the index of first occurence
    gives error if char is not found
    syntax: string.index('sub_str', start_index, end_index)
'''

s1
# Out:
# 'London bridge is falling down'

# %%
s1.index('b')
# Out:
# 7

# %%
s1.index('i')
# Out:
# 9

# %%
s1.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 s1.index('z')
#
# ValueError: substring not found

# %%
s1.index('i',12,15)
# Out:
# 14

# %%
'''
15. find()
    similar to index just that returns -1(instead of error) if char/sub string is not found
    syntax: string.find('sub_str', start_index, end_index)
'''
s1.find('i')
# Out:
# 9

# %%
s1.find('z')
# Out:
# -1

# %%
'''
16. endswith()
    checks is the string ends with a particular sub string/char
    returns a boolean value(True or False)
    use case--> to find the files with particular extension(e.g pdf, jpg, xls)
    syntax: string.endswith('suffix', start_index, end_index)
'''
# Out:
# "\n16. endswith()\n    checks is the string ends with a particular sub string/char\n    returns a boolean value(True or False)\n    use case--> to find the files with particular extension(e.g pdf, jpg, xls)\n    syntax: string.endswith('suffix', start_index, end_index)\n"

# %%
s1
# Out:
# 'London bridge is falling down'

# %%
s1.endswith('down')
# Out:
# True

# %%
s1.endswith('bridge')
# Out:
# False

# %%
s1.endswith('on')
# Out:
# False

# %%
file_path = r'C:\Users\jayes\Python Programming'
file_path.endswith('Programming')
# Out:
# True

# %%
'''
17. startswith()
    checks if the string starts with a particular sub string/char/prefix
    returns a boolean value(True or False)
    syntax: string.startswith('prefix', start_index, end_index)
'''
# Out:
# "\n17. startswith()\n    checks if the string starts with a particular sub string/char/prefix\n    returns a boolean value(True or False)\n    syntax: string.startswith('prefix', start_index, end_index)\n"

# %%
s1
# Out:
# 'London bridge is falling down'

# %%
s1.startswith('Lon')
# Out:
# True

# %%
s1.startswith('lon')
# Out:
# False

# %%
''''
18. isalnum()
    checks whether string is aplhanumeric or not(alphabets or numbers or unicode char)
    returns True or False
    syntax: string.isalnum()
'''
s1
# Out:
# 'London bridge is falling down'

# %%
s1.isalnum()
# Out:
# False

# %%
s2 = 'python'
s2.isalnum()
# Out:
# True

# %%
s3 = 'Passsword123'
s3.isalnum()
# Out:
# True

# %%
s3 = 'Password@1234'
s3.isalnum()
# Out:
# False

# %%
s = '\u2168'
s.isalnum()
# Out:
# True

# %%
'''
19. isalpha()
    • checks if the string is alphabetical
    returns boolean values
    syntax: string.isalpha()
'''
s1
# Out:
# 'London bridge is falling down'

# %%
s1.isalpha()
# Out:
# False

# %%
s2
# Out:
# 'python'

# %%
s2.isalpha()
# Out:
# True

# %%
s3
# Out:
# 'Password@1234'

# %%
s3.isalpha()
# Out:
# False

# %%
s4 = 'passwors123'
s4.isalpha()
# Out:
# False

# %%
s
# Out:
# 'Ⅸ'

# %%
s.isalpha()
# Out:
# False

# %%
s = '\u2158'
s
# Out:
# '⅘'

# %%
s.isalpha()
# Out:
# False

# %%
'''
20. isdecimal()
    checks if the string is decimal string
    syntax: string.isdecimal()
'''
s.isdecimal()
# Out:
# False

# %%
s = '325468'
s.isdecimal()
# Out:
# True

# %%
mob='8975269988'
mob.isdecimal()
# Out:
# True

# %%
'''
21. isdigit()
    it checks whether char is digit or subscript or superscript
    returns boolean values(True or False)
'''
string = '23456'
string.isdigit()
# Out:
# True

# %%
string.isdecimal()
# Out:
# True

# %%
'\u00B9'.isdecimal()
# Out:
# False

# %%
'8\u00B9'
# Out:
# '8¹'

# %%
'8\u00B9'.isdecimal()
# Out:
# False

# %%
'8\u00B9'.isdigit() #considers subscript and superscript
# Out:
# True

# %%
'10\u2070'
# Out:
# '10⁰'

# %%
'co\u2082'
# Out:
# 'co₂'

# %%
if 'CO\u2082'.isdigit():
    print("This is a digit Unicode")
else:
    print("This is not a digit Unicode")
# Out:
# This is not a digit Unicode

# %%
if '\u2082'.isdigit():
    print("This is a digit Unicode")
else:
    print("This is not a digit Unicode")
# Out:
# This is a digit Unicode

# %%
'''
22. isnumeric()
    • it checks whether char is digit or subscript or superscript or fractions
    • returns boolean values(True or False)
'''

# %%
'\u2082'.isnumeric()
# Out:
# True

# %%
'2145'.isnumeric()
# Out:
# True

# %%
'\u00BD'
# Out:
# '½'

# %%
'\u00BD'.isnumeric()
# Out:
# True

# %%
'\u00BD'.isdigit()
# Out:
# False

# %%
'\u00BD'.isdecimal()
# Out:
# False

# %%
'''Difference between isdecimal() isdigit() isnumeric()

    Parameters        isdecimal() isdigit() isnumeric()
    numeric string    True        True      True
    subscript         False       True      True
    superscript       False       True      True
    fractions         False       False     True
'''

# %%
'''
23. islower()
    checks if the string is in lower case or not
    spaces are allowed
    returns boolean values(True or False)
'''

# %%
s = 'Python'
s.islower()
# Out:
# False

# %%
s1 = 'python'
s1.islower()
# Out:
# True

# %%
if s1.islower():
    print("String is Lower case")
else:
    print("String is not in Lower case")
# Out:
# String is Lower case

# %%
'''
24. isupper()
    checks if the string is in upper case or not
    spaces are allowed
    returns boolean values(True or False)
'''

# %%
s.isupper()
# Out:
# False

# %%
s3 = 'PYTHON AND DATA STRUCTURE'
s3.isupper()
# Out:
# True

# %%
'''
25. istitle()
    checks if the string is in title case or not
    spaces are allowed
    returns boolean values
'''

# %%
s
# Out:
# 'Python'

# %%
s.istitle()
# Out:
# True

# %%
str1 = "Python And Data Science"
str1.istitle()
# Out:
# True

# %%
'''
26. isspace()
    checks if the string is made of only black spaces
    returns boolean values
'''

# %%
blank = '      '
blank.isspace()
# Out:
# True

# %%
a = '      .'
a.isspace()
# Out:
# False

# %%
# application
pan_details = """Govt of India

Name: ***** ****** ******

Father's name: ****** ***** *****

Pan no. ABCD8976H"""

# %%
expected_ouput = """Govt of India
Name: ***** ****** ******
Father's name: ****** ***** *****
Pan no. ABCD8976H"""

# %%
pan_details.split('\n')
# Out:
# ['Govt of India',
#  '',
#  'Name: ***** ****** ******',
#  '',
#  "Father's name: ****** ***** *****",
#  '',
#  'Pan no. ABCD8976H']

# %%
pan_list = pan_details.split('\n')

# %%
for line in pan_list:
#     print(line)
    if not line.isspace():
        print(line)
# Out:
# Govt of India
#
# Name: ***** ****** ******
#
# Father's name: ****** ***** *****
#
# Pan no. ABCD8976H

# %%
'''
27. join()
    used to join the elements of list or tuple or strings
    converts list or tuple into string
    syntax: 'char.join(iterable)'
'''

# %%
list1 = ['abc','lmn','xyz'] #'abclmnxyz'
''.join(list1)
# Out:
# 'abclmnxyz'

# %%
# abc**lmn**xyz
'**'.join(list1)
# Out:
# 'abc**lmn**xyz'

# %%
# abc
# lmn
# xyz
'\n'.join(list1)
# Out:
# 'abc\nlmn\nxyz'

# %%
print('\n'.join(list1))
# Out:
# abc
# lmn
# xyz

# %%
s = '\n'.join(list1)
type(s)
# Out:
# str

# %%
'''
28. center()
aligns the string to center by adding characters(default adds space) to left and right
syntax: string.center(width, fillchar=' ', /)
''''

# %%
s = 'python'
s.center(10)
# Out:
# '  python  '

# %%
s.center(20,'*')
# Out:
# '*******python*******'

# %%
len(s.center(20,'*'))
# Out:
# 20

# %%
#f-string without statement
num1 = 10
num2 = 20
string = f"Addition of {num1} and {num2} is {num1+num2}"
print(string)
# Out:
# Addition of 10 and 20 is 30

# %%
#.format string
string1 = 'Addition of {} and {} is {}'.format(num1, num2, num1+num2)
print(string1)
# Out:
# Addition of 10 and 20 is 30

# %%
#Percentage
a =10
b = 20.35
str1 = 'Addition of %d anf %f is %f'%(a,b,a+b)
print(str1)
# Out:
# Addition of 10 anf 20.350000 is 30.350000

# %%
str1 = 'Addition of %d and %.3f is %.3f'%(a,b,a+b)
print(str1)
# Out:
# Addition of 10 and 20.350 is 30.350

# %%
s = 'python'
str1 = 'Addition of %d and %f is %s'%(a,b,s)
print(str1)
# Out:
# Addition of 10 and 20.350000 is python
