# %%
str = "London bridge is fslling down"
str.replace('a',' ',-1).replace('e',' ',-1).replace('i',' ',-1).replace('o',' ',-1).replace('u',' ',-1)
# Out:
# 'L nd n br dg   s fsll ng d wn'

# %%
str.split()
# Out:
# ['London', 'bridge', 'is', 'fslling', 'dowm']

# %%
str.split('i')
# Out:
# ['London br', 'dge ', 's fsll', 'ng down']

# %%
type(str)
# Out:
# str

# %%
str.split('e','7,15')
# Out:
# ['e']

# %%
str
# Out:
# str
